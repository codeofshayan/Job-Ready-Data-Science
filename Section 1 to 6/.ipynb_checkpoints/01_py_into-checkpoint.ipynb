# %%
print("Hello, world...!")
# Out:
# Hello, world...!

# %% [markdown]
# # Python Tutorial
# Python is a general purpose object oriented programming language.
# - easy to learn
# - fun to use

# %%
a = 10

# %%
b = 7

# %%
c = a + b

# %%
c
# Out:
# 17

# %% [markdown]
# This is written in Jupyter Lab...!
